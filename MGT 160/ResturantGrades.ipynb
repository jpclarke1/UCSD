# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

rGrades = pd.read_excel("RestaurantGrades_Data.xlsx")

# %%
rGrades.shape
# Out:
# (30000, 6)

# %%
rGrades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   treatment        30000 non-null  int64
#  1   pageviews        30000 non-null  int64
#  2   calls            30000 non-null  int64
#  3   reservations     30000 non-null  int64
#  4   business_id      30000 non-null  int64
#  5   restaurant_type  30000 non-null  object
# dtypes: int64(5), object(1)
# memory usage: 1.4+ MB

# %%
rGrades.describe()
# Out:
#          treatment    pageviews         calls  reservations   business_id
# count  30000.00000  30000.00000  30000.000000  30000.000000  30000.000000
# mean       1.00000    468.06040     37.707533     36.554033  15000.500000
# std        0.81651    168.16207      7.965215      7.992309   8660.398374
# min        0.00000    145.00000     17.000000     15.000000      1.000000
# 25%        0.00000    328.00000     32.000000     31.000000   7500.750000
# 50%        1.00000    391.00000     37.000000     36.000000  15000.500000
# 75%        2.00000    636.00000     42.000000     41.000000  22500.250000
# max        2.00000    929.00000     77.000000     79.000000  30000.000000

# %%
sns.pairplot(data = rGrades, vars = ['pageviews','calls','reservations'], hue = 'treatment')
plt.show()

# %%
sns.pairplot(data = rGrades, vars = ['pageviews','calls','reservations'], hue = 'restaurant_type')
plt.show()

# %%
filterC = rGrades['restaurant_type'].isin(['chain'])
filterI = rGrades['restaurant_type'].isin(['independent'])

rChain = rGrades[filterC]
rIndep = rGrades[filterI]

# %%
rChain.describe()
# Out:
#           treatment     pageviews         calls  reservations  business_id
# count  12000.000000  12000.000000  12000.000000  12000.000000  12000.00000
# mean       1.000000    660.179667     44.056417     42.676000   6000.50000
# std        0.816531     71.591266      7.183653      7.463578   3464.24595
# min        0.000000    437.000000     19.000000     18.000000      1.00000
# 25%        0.000000    609.000000     39.000000     38.000000   3000.75000
# 50%        1.000000    660.000000     43.000000     42.000000   6000.50000
# 75%        2.000000    711.000000     48.000000     47.000000   9000.25000
# max        2.000000    929.000000     77.000000     79.000000  12000.00000

# %%
rIndep.describe()
# Out:
#           treatment     pageviews         calls  reservations   business_id
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       1.000000    339.980889     33.474944     32.472722  21000.500000
# std        0.816519     51.979719      5.152827      5.261497   5196.296758
# min        0.000000    145.000000     17.000000     15.000000  12001.000000
# 25%        0.000000    304.000000     30.000000     29.000000  16500.750000
# 50%        1.000000    339.000000     33.000000     32.000000  21000.500000
# 75%        2.000000    375.000000     37.000000     36.000000  25500.250000
# max        2.000000    530.000000     53.000000     51.000000  30000.000000

# %%
plt.bar(x=rChain.treatment, height=rChain.reservations)
plt.show()

# %%
plt.bar(x=rIndep.treatment, height=rIndep.reservations)
plt.show()

# %%
sns.scatterplot(x = 'treatment', y = 'reservations', data = rGrades, hue ='restaurant_type')
plt.show()

# %%
plt.bar(x=rGrades.treatment, height=rGrades.reservations)
plt.show()

# %%
plt.bar(x=rGrades.treatment, height=rGrades.pageviews)
plt.show()
